# %%
import os, sys
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
asd_spectra = "../CUASD/20190409_TBMT_P3C1/0048WhiteTarp1/0048WhiteTarp1_refl.spectra"
asd = pd.read_csv(asd_spectra, names=['wavelength', 'refl'], header=None, delimiter=r'\t', engine='python')

# %%
asd.head()
# Out:
#    wavelength      refl
# 0       350.0  0.052662
# 1       351.0  0.053429
# 2       352.0  0.053852
# 3       353.0  0.055150
# 4       354.0  0.056353

# %%
asd.plot(x='wavelength', y='refl', figsize=(20,10), grid=True)
